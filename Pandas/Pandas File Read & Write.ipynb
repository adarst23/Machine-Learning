# %%
import numpy as np
import pandas as pd

# %%
con = pd.read_csv('Instagram data.csv',encoding='latin-1')

# %%
con.drop('Hashtags',axis=1,inplace=True)

# %%
con.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption'],
#       dtype='object')

# %%
con['Caption'].head()
# Out:
# 0    Here are some of the most important data visua...
# 1    Here are some of the best data science project...
# 2    Learn how to train a machine learning model an...
# 3    Heres how you can write a Python program to d...
# 4    Plotting annotations while visualizing your da...
# Name: Caption, dtype: object

# %%
con.to_csv('My_output',index=False)

# %%
pd.read_csv('My_output')
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
df = pd.read_csv('serial_killers.csv')

# %%
df
# Out:
#                         Name                                  Country  \
# 0              Luis Garavito       Colombia  Ecuador[3]  Venezuela[3]
# 1                Pedro López                  Colombia  Peru  Ecuador
# 2                Javed Iqbal                                 Pakistan
# 3             Mikhail Popkov                                   Russia
# 4     Daniel Camargo Barbosa  Colombia  Ecuador  Brazil (alleged)[13]
# ...                      ...                                      ...
# 1526                 Unknown                            United States
# 1527                 Unknown                                   Canada
# 1528                 Unknown                                   Mexico
# 1529                 Unknown                                   Canada
# 1530                 Unknown                                    Italy
#
#       Years active Proven victims Possible victims  \
# 0     1992–1999[3]            193         193–300+
# ...

# %%
pd.read_excel('sampledatafoodsales.xlsx', sheet_name='FoodSales')
# Out:
#           ID       Date Region         City  Category         Product  Qty  \
# 0    ID07351 2022-01-01   East       Boston      Bars          Carrot   33
# 1    ID07352 2022-01-04   East       Boston  Crackers     Whole Wheat   87
# 2    ID07353 2022-01-07   West  Los Angeles   Cookies  Chocolate Chip   58
# 3    ID07354 2022-01-10   East     New York   Cookies  Chocolate Chip   82
# 4    ID07355 2022-01-13   East       Boston   Cookies       Arrowroot   38
# ..       ...        ...    ...          ...       ...             ...  ...
# 239  ID07590 2023-12-18   East       Boston   Cookies       Arrowroot   34
# 240  ID07591 2023-12-21   East       Boston   Cookies  Chocolate Chip  245
# 241  ID07592 2023-12-24   East       Boston  Crackers     Whole Wheat   30
# 242  ID07593 2023-12-27   West  Los Angeles      Bars            Bran   30
# 243  ID07594 2023-12-30   West  Los Angeles   Cookies  Oatmeal Raisin   44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# ...

# %%
pd.read_html('https://vincentarelbundock.github.io/Rdatasets/datasets.html')
# Out:
# [                                                Package           Item  \
#  0                                                   AER        Affairs
#  1                                                   AER   ArgentinaCPI
#  2                                                   AER      BankWages
#  3                                                   AER  BenderlyZwick
#  4                                                   AER      BondYield
#  ...                                                 ...            ...
#  2138                                         wooldridge          wage2
#  2139                                         wooldridge        wagepan
#  2140                                         wooldridge        wageprc
#  2141                                         wooldridge           wine
#  2142  Package Item Title Rows Cols n_binary n_charac...            NaN
#
#                                                    Title    Rows  Cols  \
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('My_output',engine)
# Out:
# 1531

# %%
pd.read_sql('My_output',con=engine)
# Out:
#       index                    Name                                  Country  \
# 0         0           Luis Garavito       Colombia  Ecuador[3]  Venezuela[3]
# 1         1             Pedro López                  Colombia  Peru  Ecuador
# 2         2             Javed Iqbal                                 Pakistan
# 3         3          Mikhail Popkov                                   Russia
# 4         4  Daniel Camargo Barbosa  Colombia  Ecuador  Brazil (alleged)[13]
# ...     ...                     ...                                      ...
# 1526   1526                 Unknown                            United States
# 1527   1527                 Unknown                                   Canada
# 1528   1528                 Unknown                                   Mexico
# 1529   1529                 Unknown                                   Canada
# 1530   1530                 Unknown                                    Italy
#
# ...
